# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
fact_df = pd.read_csv('data/fact_table.csv', encoding='ISO-8859-1')
customer_df = pd.read_csv('data/customer_dim.csv', encoding='ISO-8859-1')
item_df = pd.read_csv('data/item_dim.csv', encoding='ISO-8859-1')
store_df = pd.read_csv('data/store_dim.csv', encoding='ISO-8859-1')
time_df = pd.read_csv('data/time_dim.csv', encoding='ISO-8859-1')

# %%
df = (
    fact_df.merge(time_df, how='left', on='time_key')
    .merge(item_df, how='left', on='item_key')
    .merge(customer_df, how='left', on='coustomer_key')
)

# %%
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y %H:%M')
df['minute'] = df['date'].dt.minute
df['date'] = pd.to_datetime(df['date'].dt.date)

# %%
product_journey_df = df.sort_values(by=['coustomer_key', 'date'])
product_journey_df['next_item_bought'] = product_journey_df.groupby('coustomer_key')['item_name'].shift(-1)
product_journey_df = product_journey_df.dropna(subset=['next_item_bought']).reset_index()
product_journey_df = product_journey_df[['coustomer_key','item_key','date','quantity','total_price','item_name','next_item_bought']]
product_journey_df
# Out:
#        coustomer_key item_key       date  quantity  total_price  \
# 0            C000001   I00137 2014-02-06        11        264.0
# 1            C000001   I00167 2014-02-21         7         98.0
# 2            C000001   I00204 2014-02-22         6        102.0
# 3            C000001   I00113 2014-04-03         2         84.0
# 4            C000001   I00139 2014-05-18         7        168.0
# ...              ...      ...        ...       ...          ...
# 990804       C009191   I00118 2020-11-01         3        126.0
# 990805       C009191   I00118 2020-11-30         6        252.0
# 990806       C009191   I00186 2020-12-06         2         26.0
# 990807       C009191   I00257 2020-12-17         6        126.0
# 990808       C009191   I00024 2020-12-26         8        130.0
#
#                                            item_name  \
# 0                        Foam Coffee Cups - 08 ounce
# 1                       Pringles Snak Stacks Variety
# 2       Nature Valley Biscuit Sandwich Variety Pack
# 3                      K Cups - McCafe Premium Roast
# 4                        Foam Coffee Cups - 16 ounce
# ...                                              ...
# 990804               K Cups Organic Breakfast Blend
# 990805               K Cups Organic Breakfast Blend
# 990806               Belvita Hard Biscuits Blueberry
# 990807                 Large Trash Bags Black 33 gal
# 990808                            Pepsi - 12 oz cans
#
#                                     next_item_bought
# 0                       Pringles Snak Stacks Variety
# 1       Nature Valley Biscuit Sandwich Variety Pack
# 2                      K Cups - McCafe Premium Roast
# 3                        Foam Coffee Cups - 16 ounce
# 4              Tylenol Extra Strength 2 pill packets
# ...                                              ...
# 990804               K Cups Organic Breakfast Blend
# 990805               Belvita Hard Biscuits Blueberry
# 990806                 Large Trash Bags Black 33 gal
# 990807                            Pepsi - 12 oz cans
# 990808            Paper Plates 8.5 inch Ultra Strong
#
# [990809 rows x 7 columns]

# %%
all_products = list(set(product_journey_df['item_name']).union(set(product_journey_df['next_item_bought'])))

# Create a mapping from product name to index
product_to_index = {product: i for i, product in enumerate(all_products)}

# Create source and target indices
product_journey_df['source'] = product_journey_df['item_name'].map(product_to_index)
product_journey_df['target'] = product_journey_df['next_item_bought'].map(product_to_index)

# Aggregate data for Sankey diagram
sankey_data = product_journey_df.groupby(['source', 'target']).size().reset_index(name='value').sort_values('value', ascending=False).iloc[:25]

# Create the Sankey diagram
fig = go.Figure(data=[go.Sankey(
    node=dict(
        pad=15,
        thickness=20,
        line=dict(color="black", width=0.5),
        label=[product for product in all_products]
    ),
    link=dict(
        source=sankey_data['source'],
        target=sankey_data['target'],
        value=sankey_data['value']
    )
)])

fig.update_layout(title_text="Customer Journey of Items Purchased", font_size=10)
fig.show()

# %%
from efficient_apriori import apriori

basket = df.groupby(['coustomer_key', 'item_name'])['quantity'].sum().unstack().reset_index().fillna(0).set_index('coustomer_key')
min_purchase_threshold = 23000
min_customer_threshold = 650

product_counts = basket.sum(axis=0)
filtered_products = product_counts[product_counts >= min_purchase_threshold].index
basket_filtered = basket[filtered_products]

customer_sums = basket.sum(axis=1)
filtered_customers = customer_sums[customer_sums >= min_customer_threshold].index
basket_filtered = basket_filtered.loc[filtered_customers]

basket = basket_filtered.applymap(lambda x: 1 if x > 4 else 0)

# %%
basket.shape
# Out:
# (4691, 64)

# %%
transactions = basket.apply(lambda row: [product for product in basket.columns if row[product] == 1], axis=1).tolist()

itemsets, rules = apriori(transactions, min_support=0.05, min_confidence=0.5)

# %%
itemsets[3]
# Out:
# {('100% Juice Box Variety 6.75 oz ',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 255,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 248,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 259,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 254,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 240,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 255,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 242,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 254,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 236,
#  ('100% Juice Box Variety 6.75 oz ',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 245,
#  ('A&W Root Beer - 12 oz cans',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 246,
#  ('A&W Root Beer - 12 oz cans',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 239,
#  ('A&W Root Beer - 12 oz cans',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 245,
#  ('A&W Root Beer - 12 oz cans',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 238,
#  ('A&W Root Beer - 12 oz cans',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 264,
#  ('A&W Root Beer - 12 oz cans',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 275,
#  ('A&W Root Beer - 12 oz cans',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 272,
#  ('A&W Root Beer - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 257,
#  ('A&W Root Beer - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 241,
#  ('A&W Root Beer - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 272,
#  ('A&W Root Beer Diet - 12 oz cans',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 241,
#  ('A&W Root Beer Diet - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 253,
#  ('A&W Root Beer Diet - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 238,
#  ('Advil 2 pill packets',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 272,
#  ('Advil 2 pill packets',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 261,
#  ('Advil 2 pill packets',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 268,
#  ('Advil 2 pill packets',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 263,
#  ('Advil 2 pill packets',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 258,
#  ('Advil 2 pill packets', 'Diet Coke - 12 oz cans', 'Pepsi - 12 oz cans'): 265,
#  ('Advil 2 pill packets',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 274,
#  ('Advil 2 pill packets',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 253,
#  ('Advil 2 pill packets',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 275,
#  ('Advil 2 pill packets', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 270,
#  ('Baked Chips Variety Mix Frito',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 273,
#  ('Baked Chips Variety Mix Frito',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 260,
#  ('Baked Chips Variety Mix Frito',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 260,
#  ('Baked Chips Variety Mix Frito',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 251,
#  ('Baked Chips Variety Mix Frito',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 267,
#  ('Baked Chips Variety Mix Frito',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 255,
#  ('Baked Chips Variety Mix Frito',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 252,
#  ('Baked Chips Variety Mix Frito',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 246,
#  ('Baked Chips Variety Mix Frito',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 236,
#  ('Baked Chips Variety Mix Frito',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 251,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 263,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 250,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 274,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 249,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 257,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 263,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 244,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 260,
#  ('Belvita Hard Biscuits Cinnamon',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 276,
#  ('Cascade Gel Packs Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 252,
#  ('Cascade Gel Packs Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 250,
#  ('Cascade Gel Packs Dishwasher',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 256,
#  ('Cascade Gel Packs Dishwasher',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 239,
#  ('Cascade Gel Packs Dishwasher',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 253,
#  ('Cascade Gel Packs Dishwasher',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 254,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 260,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 258,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 252,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 249,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 243,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 264,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 254,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 244,
#  ('Cascade Gel w/ Dawn Dishwasher',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 256,
#  ('Charmin Ultra Bath Tissue',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 251,
#  ('Charmin Ultra Bath Tissue',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 238,
#  ('Charmin Ultra Bath Tissue',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 260,
#  ('Charmin Ultra Bath Tissue',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 245,
#  ('Charmin Ultra Bath Tissue',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 239,
#  ('Charmin Ultra Bath Tissue',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 255,
#  ('Charmin Ultra Bath Tissue',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 236,
#  ('Charmin Ultra Bath Tissue',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 263,
#  ('Charmin Ultra Bath Tissue',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 235,
#  ('Charmin Ultra Bath Tissue',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 256,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 250,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 244,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 253,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 254,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 244,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 244,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 265,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 246,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 274,
#  ('Cheez It White Cheddar 1.5 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 259,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 264,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 235,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 260,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 237,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 262,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 243,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 255,
#  ('Chinet Comfort Hot Cups with Lids 16oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 250,
#  ('Clear Plastic Cups 9oz',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 251,
#  ('Clear Plastic Cups 9oz',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 251,
#  ('Clear Plastic Cups 9oz',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 236,
#  ('Clear Plastic Cups 9oz',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 251,
#  ('Clear Plastic Cups 9oz',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 244,
#  ('Clear Plastic Cups 9oz',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 267,
#  ('Clear Plastic Cups 9oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 241,
#  ('Clear Plastic Cups 9oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 242,
#  ('Clear Plastic Cups 9oz', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 248,
#  ('Clorox Bleach Large Jugs',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 254,
#  ('Clorox Bleach Large Jugs',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 261,
#  ('Clorox Bleach Large Jugs',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 257,
#  ('Clorox Bleach Large Jugs',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 240,
#  ('Clorox Bleach Large Jugs',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 241,
#  ('Clorox Bleach Large Jugs',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 272,
#  ('Clorox Bleach Large Jugs',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 248,
#  ('Clorox Bleach Large Jugs',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 249,
#  ('Coffee-Mate French Vanilla Cold',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 287,
#  ('Coffee-Mate French Vanilla Cold',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 268,
#  ('Coffee-Mate French Vanilla Cold',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 263,
#  ('Coffee-Mate French Vanilla Cold',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 265,
#  ('Coffee-Mate French Vanilla Cold',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 262,
#  ('Coffee-Mate French Vanilla Cold',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 243,
#  ('Coffee-Mate French Vanilla Cold',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 254,
#  ('Coffee-Mate Original Flavor Cold',
#   'Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans'): 273,
#  ('Coffee-Mate Original Flavor Cold',
#   'Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 246,
#  ('Coffee-Mate Original Flavor Cold',
#   'Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans'): 242,
#  ('Coffee-Mate Original Flavor Cold',
#   'Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans'): 239,
#  ('Coffee-Mate Original Flavor Cold',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 245,
#  ('Coffee-Mate Original Flavor Cold',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 268,
#  ('Coffee-Mate Original Flavor Cold',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 248,
#  ('Coffee-Mate Original Flavor Cold',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 241,
#  ('Coffee-Mate Original Flavor Cold',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 242,
#  ('Coffee-Mate Original Flavor Cold',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 256,
#  ('Coke Classic 12 oz cans',
#   'Detour Lower Sugar Protein Bar',
#   'Diet Coke - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   'Detour Lower Sugar Protein Bar',
#   'Muscle Milk Protein Shake Van. 11oz'): 260,
#  ('Coke Classic 12 oz cans',
#   'Detour Lower Sugar Protein Bar',
#   'Pepsi - 12 oz cans'): 264,
#  ('Coke Classic 12 oz cans',
#   'Detour Lower Sugar Protein Bar',
#   'Sprite - 12 oz cans'): 251,
#  ('Coke Classic 12 oz cans',
#   'Diet Coke - 12 oz cans',
#   '
12 oz cans',
#   'K Cups Dunkin Donuts Medium Roast',
#   'Muscle Milk Protein Shake Van. 11oz'): 244,
#  ('Coke Classic 12 oz cans',
#   'K Cups Dunkin Donuts Medium Roast',
#   'Pepsi - 12 oz cans'): 237,
#  ('Coke Classic 12 oz cans',
#   'K Cups Dunkin Donuts Medium Roast',
#   'Sprite - 12 oz cans'): 245,
#  ('Coke Classic 12 oz cans',
#   "Kellogg's Cereals Assortment Pack ",
#   'Muscle Milk Protein Shake Van. 11oz'): 239,
#  ('Coke Classic 12 oz cans',
#   "Kellogg's Cereals Assortment Pack ",
#   'Pepsi - 12 oz cans'): 271,
#  ('Coke Classic 12 oz cans',
#   "Kellogg's Cereals Assortment Pack ",
#   'Sprite - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   'La Croix Sparkling Grapefruit 12 oz',
#   'Muscle Milk Protein Shake Van. 11oz'): 245,
#  ('Coke Classic 12 oz cans',
#   'La Croix Sparkling Grapefruit 12 oz',
#   'Pepsi - 12 oz cans'): 239,
#  ('Coke Classic 12 oz cans',
#   'La Croix Sparkling Grapefruit 12 oz',
#   'Sprite - 12 oz cans'): 239,
#  ('Coke Classic 12 oz cans',
#   'Large Trash Bags Black 33 gal',
#   'Pepsi - 12 oz cans'): 257,
#  ('Coke Classic 12 oz cans',
#   'M&M Peanut Butter 1.6 oz',
#   'Muscle Milk Protein Shake Van. 11oz'): 260,
#  ('Coke Classic 12 oz cans',
#   'M&M Peanut Butter 1.6 oz',
#   'Pepsi - 12 oz cans'): 261,
#  ('Coke Classic 12 oz cans',
#   'M&M Peanut Butter 1.6 oz',
#   'Sprite - 12 oz cans'): 255,
#  ('Coke Classic 12 oz cans',
#   'Miss Vickies Chips',
#   'Muscle Milk Protein Shake Van. 11oz'): 254,
#  ('Coke Classic 12 oz cans', 'Miss Vickies Chips', 'Sprite - 12 oz cans'): 252,
#  ('Coke Classic 12 oz cans',
#   'Monster Original Green 16 oz',
#   'Pepsi - 12 oz cans'): 238,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Strbry. 11oz',
#   'Muscle Milk Protein Shake Van. 11oz'): 247,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Strbry. 11oz',
#   'Pepsi - 12 oz cans'): 245,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Strbry. 11oz',
#   'Sprite - 12 oz cans'): 251,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Nabisco Classic Mix ccooki, cracker'): 237,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Nabisco Cookie Variety Pk Oreo/ChocChip'): 246,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Napkins Square Lunch'): 253,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Njoy Sugar Canister 22 oz'): 262,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Ocean Spray Cranberry Juice Cocktail 15oz '): 251,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Paper Plates 7 inch  Ultra Strong'): 250,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 445,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pop Chips Variety bags'): 255,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pop-Tarts, Brown Sugar Cinnamon '): 247,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Quaker Instant Oatmeal Maple Brn Sugar'): 274,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Red Bull 8.4 oz'): 252,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Red Bull Sugar Free 8.4 oz'): 253,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   "Reese's Peanutbutter Cups 2/pk"): 239,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   "Reese's Pieces Peanutbutter Candy"): 278,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sobe Zero Lifewater Variety 20 oz'): 255,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 408,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   "Starbuck's Pike Place"): 253,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sweet N Low Sweetener'): 240,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 238,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Tropicana Apple Juice 10 oz 100% '): 236,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Waterloo Sparkling Mango 12oz'): 252,
#  ('Coke Classic 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Wonderful Pistachios (in shell)'): 250,
#  ('Coke Classic 12 oz cans',
#   'Nabisco Classic Mix ccooki, cracker',
#   'Pepsi - 12 oz cans'): 270,
#  ('Coke Classic 12 oz cans',
#   'Nabisco Classic Mix ccooki, cracker',
#   'Sprite - 12 oz cans'): 248,
#  ('Coke Classic 12 oz cans',
#   'Nabisco Cookie Variety Pk Oreo/ChocChip',
#   'Pepsi - 12 oz cans'): 238,
#  ('Coke Classic 12 oz cans',
#   'Nabisco Cookie Variety Pk Oreo/ChocChip',
#   'Sprite - 12 oz cans'): 245,
#  ('Coke Classic 12 oz cans',
#   'Napkins Square Lunch',
#   'Pepsi - 12 oz cans'): 263,
#  ('Coke Classic 12 oz cans',
#   'Nat.Valley PeanutButter Protein Bars',
#   'Sprite - 12 oz cans'): 240,
#  ('Coke Classic 12 oz cans',
#   'Njoy Sugar Canister 22 oz',
#   'Pepsi - 12 oz cans'): 258,
#  ('Coke Classic 12 oz cans',
#   'Njoy Sugar Canister 22 oz',
#   'Sprite - 12 oz cans'): 242,
#  ('Coke Classic 12 oz cans',
#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Pepsi - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Sprite - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Pepsi - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Sprite - 12 oz cans'): 269,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Planters Nut-trition 1.5 oz '): 242,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Pop Chips Variety bags'): 244,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon '): 249,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar'): 259,
#  ('Coke Classic 12 oz cans', 'Pepsi - 12 oz cans', 'Red Bull 12oz'): 242,
#  ('Coke Classic 12 oz cans', 'Pepsi - 12 oz cans', 'Red Bull 8.4 oz'): 256,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz'): 246,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy"): 257,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz'): 259,
#  ('Coke Classic 12 oz cans', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 438,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   "Starbuck's Pike Place"): 262,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sweet N Low Sweetener'): 235,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 271,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 256,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Mango 12oz'): 269,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 249,
#  ('Coke Classic 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 244,
#  ('Coke Classic 12 oz cans',
#   'Planters Nut-trition 1.5 oz ',
#   'Sprite - 12 oz cans'): 244,
#  ('Coke Classic 12 oz cans',
#   'Pop Chips Variety bags',
#   'Sprite - 12 oz cans'): 251,
#  ('Coke Classic 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon ',
#   'Sprite - 12 oz cans'): 243,
#  ('Coke Classic 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar',
#   'Sprite - 12 oz cans'): 253,
#  ('Coke Classic 12 oz cans', 'Red Bull 8.4 oz', 'Sprite - 12 oz cans'): 254,
#  ('Coke Classic 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz',
#   'Sprite - 12 oz cans'): 259,
#  ('Coke Classic 12 oz cans',
#   "Reese's Peanutbutter Cups 2/pk",
#   'Sprite - 12 oz cans'): 235,
#  ('Coke Classic 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy",
#   'Sprite - 12 oz cans'): 268,
#  ('Coke Classic 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz',
#   'Sprite - 12 oz cans'): 255,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   "Starbuck's Pike Place"): 251,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Sweet N Low Sweetener'): 238,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 255,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Vita Coconut Water 10oz '): 248,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Mango 12oz'): 248,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 236,
#  ('Coke Classic 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 250,
#  ('Detour Lower Sugar Protein Bar',
#   'Diet Coke - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 246,
#  ('Detour Lower Sugar Protein Bar',
#   'Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans'): 245,
#  ('Detour Lower Sugar Protein Bar',
#   'Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans'): 250,
#  ('Detour Lower Sugar Protein Bar',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 263,
#  ('Detour Lower Sugar Protein Bar',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 246,
#  ('Detour Lower Sugar Protein Bar',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 258,
#  ('Diet Coke - 12 oz cans',
#   'Diet Pepsi - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 245,
#  ('Diet Coke - 12 oz cans',
#   'Diet Pepsi - 12 oz cans',
#   'Pepsi - 12 oz cans'): 259,
#  ('Diet Coke - 12 oz cans',
#   'Diet Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 253,
#  ('Diet Coke - 12 oz cans',
#   'Doritos Nacho Cheese 1 oz',
#   'Muscle Milk Protein Shake Van. 11oz'): 242,
#  ('Diet Coke - 12 oz cans',
#   'Doritos Nacho Cheese 1 oz',
#   'Pepsi - 12 oz cans'): 271,
#  ('Diet Coke - 12 oz cans',
#   'Foam Coffee Cups - 20 ounce',
#   'Muscle Milk Protein Shake Van. 11oz'): 235,
#  ('Diet Coke - 12 oz cans',
#   'Foam Coffee Cups - 20 ounce',
#   'Pepsi - 12 oz cans'): 259,
#  ('Diet Coke - 12 oz cans',
#   'Foam Coffee Cups - 20 ounce',
#   'Sprite - 12 oz cans'): 237,
#  ('Diet Coke - 12 oz cans',
#   'Frito Classic Mix Variety',
#   'Pepsi - 12 oz cans'): 250,
#  ('Diet Coke - 12 oz cans',
#   'Gatorade Variety 20 oz ',
#   'Muscle Milk Protein Shake Van. 11oz'): 248,
#  ('Diet Coke - 12 oz cans',
#   'Gatorade Variety 20 oz ',
#   'Pepsi - 12 oz cans'): 247,
#  ('Diet Coke - 12 oz cans',
#   'Gatorade Variety 20 oz ',
#   'Sprite - 12 oz cans'): 252,
#  ('Diet Coke - 12 oz cans',
#   'Ginger Ale - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz'): 237,
#  ('Diet Coke - 12 oz cans',
#   'Ginger Ale - 12 oz cans',
#   'Pepsi - 12 oz cans'): 246,
#  ('Diet Coke - 12 oz cans',
#   'Hand Sanitizer Refill Pump',
#   'Muscle Milk Protein Shake Van. 11oz'): 247,
#  ('Diet Coke - 12 oz cans',
#   'Hand Sanitizer Refill Pump',
#   'Pepsi - 12 oz cans'): 281,
#  ('Diet Coke - 12 oz cans',
#   'Hand Sanitizer Refill Pump',
#   'Sprite - 12 oz cans'): 282,
#  ('Diet Coke - 12 oz cans',
#   'K Cups Daily Chef Columbian Supremo',
#   '

#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Pepsi - 12 oz cans'): 235,
#  ('Diet Coke - 12 oz cans',
#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Sprite - 12 oz cans'): 246,
#  ('Diet Coke - 12 oz cans',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Pepsi - 12 oz cans'): 241,
#  ('Diet Coke - 12 oz cans',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Sprite - 12 oz cans'): 250,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Planters Nut-trition 1.5 oz '): 255,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Pop Chips Variety bags'): 251,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon '): 256,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar'): 265,
#  ('Diet Coke - 12 oz cans', 'Pepsi - 12 oz cans', 'Red Bull 12oz'): 256,
#  ('Diet Coke - 12 oz cans', 'Pepsi - 12 oz cans', 'Red Bull 8.4 oz'): 267,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz'): 255,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   "Reese's Peanutbutter Cups 2/pk"): 248,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy"): 238,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz'): 245,
#  ('Diet Coke - 12 oz cans', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 440,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Spunkmeyer Muffin Variety'): 237,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   "Starbuck's Pike Place"): 245,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Sweet N Low Sweetener'): 257,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 247,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Topo Chico 20oz plastic'): 243,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 272,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Vita Coconut Water 10oz '): 242,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Mango 12oz'): 244,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 250,
#  ('Diet Coke - 12 oz cans',
#   'Pepsi - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 265,
#  ('Diet Coke - 12 oz cans',
#   'Planters Nut-trition 1.5 oz ',
#   'Sprite - 12 oz cans'): 257,
#  ('Diet Coke - 12 oz cans',
#   'Pop Chips Variety bags',
#   'Sprite - 12 oz cans'): 243,
#  ('Diet Coke - 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon ',
#   'Sprite - 12 oz cans'): 273,
#  ('Diet Coke - 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar',
#   'Sprite - 12 oz cans'): 258,
#  ('Diet Coke - 12 oz cans', 'Red Bull 8.4 oz', 'Sprite - 12 oz cans'): 235,
#  ('Diet Coke - 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz',
#   'Sprite - 12 oz cans'): 264,
#  ('Diet Coke - 12 oz cans',
#   "Reese's Peanutbutter Cups 2/pk",
#   'Sprite - 12 oz cans'): 255,
#  ('Diet Coke - 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy",
#   'Sprite - 12 oz cans'): 262,
#  ('Diet Coke - 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz',
#   'Sprite - 12 oz cans'): 242,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Sweet N Low Sweetener'): 244,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 236,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Topo Chico 20oz plastic'): 258,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 279,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Vita Coconut Water 10oz '): 246,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 245,
#  ('Diet Coke - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 258,
#  ('Diet Pepsi - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 252,
#  ('Diet Pepsi - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 260,
#  ('Diet Pepsi - 12 oz cans', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 253,
#  ('Doritos Nacho Cheese 1 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 261,
#  ('Doritos Nacho Cheese 1 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 257,
#  ('Doritos Nacho Cheese 1 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 270,
#  ('Foam Coffee Cups - 20 ounce',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 258,
#  ('Foam Coffee Cups - 20 ounce',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 261,
#  ('Foam Coffee Cups - 20 ounce',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 268,
#  ('Frito Classic Mix Variety',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 240,
#  ('Frito Classic Mix Variety',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 239,
#  ('Frito Classic Mix Variety',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 246,
#  ('Gatorade Variety 20 oz ',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 247,
#  ('Gatorade Variety 20 oz ',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 239,
#  ('Gatorade Variety 20 oz ', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 251,
#  ('Ginger Ale - 12 oz cans',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 259,
#  ('Ginger Ale - 12 oz cans', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 247,
#  ('Hand Sanitizer Refill Pump',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 259,
#  ('Hand Sanitizer Refill Pump',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 255,
#  ('Hand Sanitizer Refill Pump',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 256,
#  ('K Cups Daily Chef Columbian Supremo',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 285,
#  ('K Cups Daily Chef Columbian Supremo',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 270,
#  ('K Cups Daily Chef Columbian Supremo',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 269,
#  ('K Cups Dunkin Donuts Medium Roast',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 237,
#  ('K Cups Dunkin Donuts Medium Roast',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 245,
#  ('K Cups Dunkin Donuts Medium Roast',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 247,
#  ("Kellogg's Cereals Assortment Pack ",
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 244,
#  ("Kellogg's Cereals Assortment Pack ",
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 246,
#  ("Kellogg's Cereals Assortment Pack ",
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 271,
#  ('La Croix Sparkling Grapefruit 12 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 249,
#  ('La Croix Sparkling Grapefruit 12 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 237,
#  ('La Croix Sparkling Grapefruit 12 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 248,
#  ('Large Trash Bags Black 33 gal',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 256,
#  ('Large Trash Bags Black 33 gal',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 238,
#  ('M&M Peanut Butter 1.6 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 242,
#  ('M&M Peanut Butter 1.6 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 270,
#  ('M&M Peanut Butter 1.6 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 252,
#  ('Miss Vickies Chips',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 239,
#  ('Miss Vickies Chips', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 243,
#  ('Monster Original Green 16 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 236,
#  ('Monster Original Green 16 oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 243,
#  ('Monster Original Green 16 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 263,
#  ('Muscle Milk Protein Shake Strbry. 11oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans'): 240,
#  ('Muscle Milk Protein Shake Strbry. 11oz',
#   'Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans'): 251,
#  ('Muscle Milk Protein Shake Strbry. 11oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 258,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Nabisco Classic Mix ccooki, cracker',
#   'Pepsi - 12 oz cans'): 256,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Nabisco Classic Mix ccooki, cracker',
#   'Sprite - 12 oz cans'): 241,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Nabisco Cookie Variety Pk Oreo/ChocChip',
#   'Sprite - 12 oz cans'): 246,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Napkins Square Lunch',
#   'Pepsi - 12 oz cans'): 250,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Nat.Valley PeanutButter Protein Bars',
#   'Pepsi - 12 oz cans'): 252,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Nat.Valley PeanutButter Protein Bars',
#   'Sprite - 12 oz cans'): 237,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Njoy Sugar Canister 22 oz',
#   'Pepsi - 12 oz cans'): 258,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Njoy Sugar Canister 22 oz',
#   'Sprite - 12 oz cans'): 251,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Pepsi - 12 oz cans'): 236,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Sprite - 12 oz cans'): 246,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Pepsi - 12 oz cans'): 248,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Paper Plates 7 inch  Ultra Strong',
#   'Sprite - 12 oz cans'): 237,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Planters Nut-trition 1.5 oz '): 241,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Pop Chips Variety bags'): 263,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon '): 243,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar'): 265,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Red Bull 12oz'): 244,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Red Bull 8.4 oz'): 248,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz'): 242,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   "Reese's Peanutbutter Cups 2/pk"): 238,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy"): 261,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz'): 238,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 459,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   "Starbuck's Pike Place"): 250,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Sweet N Low Sweetener'): 268,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 243,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 243,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Vita Coconut Water 10oz '): 240,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Mango 12oz'): 244,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 257,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pepsi - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 238,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pop Chips Variety bags',
#   'Sprite - 12 oz cans'): 249,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Pop-Tarts, Brown Sugar Cinnamon ',
#   'Sprite - 12 oz cans'): 242,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Quaker Instant Oatmeal Maple Brn Sugar',
#   'Sprite - 12 oz cans'): 261,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Red Bull 12oz',
#   'Sprite - 12 oz cans'): 235,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Red Bull 8.4 oz',
#   'Sprite - 12 oz cans'): 242,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Red Bull Sugar Free 8.4 oz',
#   'Sprite - 12 oz cans'): 245,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   "Reese's Peanutbutter Cups 2/pk",
#   'Sprite - 12 oz cans'): 235,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   "Reese's Pieces Peanutbutter Candy",
#   'Sprite - 12 oz cans'): 270,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sobe Zero Lifewater Variety 20 oz',
#   'Sprite - 12 oz cans'): 239,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Sweet N Low Sweetener'): 240,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 235,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Topo Chico 20oz plastic'): 250,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 237,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Vita Coconut Water 10oz '): 249,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 241,
#  ('Muscle Milk Protein Shake Van. 11oz',
#   'Sprite - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 253,
#  ('Nabisco Classic Mix ccooki, cracker',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 260,
#  ('Nabisco Cookie Variety Pk Oreo/ChocChip',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 238,
#  ('Napkins Square Lunch', 'Pepsi - 12 oz cans', 'Sprite - 12 oz cans'): 258,
#  ('Nat.Valley PeanutButter Protein Bars',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 249,
#  ('Njoy Sugar Canister 22 oz',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 255,
#  ('Ocean Spray Cranberry Juice Cocktail 15oz ',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 257,
#  ('Paper Plates 7 inch  Ultra Strong',
#   'Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans'): 257,
#  ('Pepsi - 12 oz cans',
#   'Planters Nut-trition 1.5 oz ',
#   'Sprite - 12 oz cans'): 260,
#  ('Pepsi - 12 oz cans', 'Pop Chips Variety bags', 'Sprite - 12 oz cans'): 245,
#  ('Pepsi - 12 oz cans',
#   'Pop-Tarts, Brown Sugar Cinnamon ',
#   'Sprite - 12 oz cans'): 282,
#  ('Pepsi - 12 oz cans',
#   'Quaker Instant Oatmeal Maple Brn Sugar',
#   'Sprite - 12 oz cans'): 261,
#  ('Pepsi - 12 oz cans', 'Red Bull 12oz', 'Sprite - 12 oz cans'): 242,
#  ('Pepsi - 12 oz cans', 'Red Bull 8.4 oz', 'Sprite - 12 oz cans'): 241,
#  ('Pepsi - 12 oz cans',
#   'Red Bull Sugar Free 8.4 oz',
#   'Sprite - 12 oz cans'): 248,
#  ('Pepsi - 12 oz cans',
#   "Reese's Peanutbutter Cups 2/pk",
#   'Sprite - 12 oz cans'): 241,
#  ('Pepsi - 12 oz cans',
#   "Reese's Pieces Peanutbutter Candy",
#   'Sprite - 12 oz cans'): 257,
#  ('Pepsi - 12 oz cans',
#   'Sobe Zero Lifewater Variety 20 oz',
#   'Sprite - 12 oz cans'): 252,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Spunkmeyer Muffin Variety'): 244,
#  ('Pepsi - 12 oz cans', 'Sprite - 12 oz cans', "Starbuck's Pike Place"): 239,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Swiss Miss Hot Cocoa Mix 1 oz'): 265,
#  ('Pepsi - 12 oz cans', 'Sprite - 12 oz cans', 'Topo Chico 20oz plastic'): 248,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Tropicana Apple Juice 10 oz 100% '): 242,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Vita Coconut Water 10oz '): 252,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Mango 12oz'): 240,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Waterloo Sparkling Original 12oz'): 253,
#  ('Pepsi - 12 oz cans',
#   'Sprite - 12 oz cans',
#   'Wonderful Pistachios (in shell)'): 260}

# %%
len(rules)
# Out:
# 9

# %%
top_itemsets = itemsets.nlargest(10, 'support')
top_itemsets['itemsets'] = top_itemsets['itemsets'].apply(lambda x: ', '.join(x))

plt.figure(figsize=(10, 6))
plt.barh(top_itemsets['itemsets'], top_itemsets['support'], color='skyblue')
plt.xlabel('Support')
plt.ylabel('Itemsets')
plt.title('Top 10 Frequent Itemsets')
plt.gca().invert_yaxis()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 top_itemsets = itemsets.nlargest(10, 'support')
#       2 top_itemsets['itemsets'] = top_itemsets['itemsets'].apply(lambda x: ', '.join(x))
#       4 plt.figure(figsize=(10, 6))
#
# AttributeError: 'dict' object has no attribute 'nlargest'
